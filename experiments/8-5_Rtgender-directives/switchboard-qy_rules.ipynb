# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Switchboard

# %%
swda = pd.read_csv('/nas/home/jwei/biases/dialog-bias/Switchboard-Corpus/swda_data/full_set.txt', \
                   delimiter='|', header=None)
swda.columns = ['speaker', 'utterance', 'act']

swda.utterance = swda.utterance.astype(str)
swda['is_qy'] = swda['act'] == 'qy'

swda
# Out:
#        speaker  \
# 0            A
# 1            A
# 2            B
# 3            A
# 4            B
# ...        ...
# 199757       B
# 199758       B
# 199759       B
# 199760       B
# 199761       A
#
#                                                                                       utterance  \
# 0                                                                                         Okay.
# 1                        So, What kind of experience do you, do you have, then with child care?
# 2                                                I guess, I think, uh, I wonder if that worked.
# 3                                                                        Does it say something?
# 4                                                                      I think it usually does.
# ...                                                                                         ...
# 199757                               and I know they've, there's a lot of refineries down there
# 199758                        and that, that's some pretty potent stuff they put up in the air.
# 199759                                                   I, but I don't know how, uh, you know,
# 199760       there's a difference in what you can smell and what you, uh, you know, what's bad.
# 199761  Be interesting to see when, as Mexico develops industrially whether, you know, without,
#
#                     act  is_qy
# 0       fo_o_fw_"_by_bc  False
# 1                    qw  False
# 2                  qy^d  False
# 3                    qy   True
# 4                    sd  False
# ...                 ...    ...
# 199757               sd  False
# 199758               sv  False
# 199759               sd  False
# 199760               sv  False
# 199761               sv  False
#
# [199762 rows x 4 columns]

# %%
swda[swda['is_qy']].sample(30)
# Out:
#        speaker  \
# 32382        B
# 101597       A
# 74708        B
# 171604       A
# 161404       B
# 36230        B
# 185678       A
# 120286       B
# 165218       A
# 31146        A
# 88471        B
# 156333       B
# 11500        B
# 12469        A
# 48146        A
# 53672        A
# 22945        B
# 194059       A
# 84040        A
# 28565        B
# 150841       A
# 107986       A
# 156495       B
# 46040        A
# 22595        B
# 87083        A
# 192013       B
# 67591        B
# 99103        B
# 82074        A
#
#                                                                                                                           utterance  \
# 32382                                                                                           is it along the coast or or inland.
# 101597         well, uh, have there been significant changes, uh, do you think in the employment place, especially, uh, say at T I.
# 74708                                                                                                         Do you want to start?
# 171604                                                                                      Uh, did they make the movies after that
# 161404                                                        Doesn't it just, uh, do they have to go back and do a whole new trial
# 36230                                                                                     You didn't have to mix paint then, right.
# 185678                                                                                                               Are you there?
# 120286                                                                          Doesn't this, doesn't this encourage,  Uh,   More .
# 165218  Well, do you think the U S should even be involved? I mean, as the world leader in the sense trying to resolve these issues
# 31146                                                                                  Do you get, do you work at home all the time
# 88471                                                                                                        Do you have  a family?
# 156333                                                                                                     Is he still around here?
# 11500                                                                             was  that in your home or in someone else's home?
# 12469                                                                                                             now, do you work?
# 48146                                                                        did you receive information from your skiing magazine?
# 53672                                                                               You know, Karen, I wonder if  we are recording.
# 22945                                                                                       it just doesn't seem possible, does it.
# 194059                                                                                                        Do you have any pets?
# 84040                                                   Well, the thing is, is that, um, I I basically know how much I have, right?
# 28565                                                                                                             Was he  murdered?
# 150841                                                                                                  Wouldn't that be something?
# 107986                                                                                       Shouldn't we try and help our friends?
# 156495                                                                                     have you had any former Suzuki students?
# 46040                                                                                               Do you live in the Dallas area?
# 22595                                                                                                    So, do you watch much T V,
# 87083                                                                                             Um. Do you watch it every Sunday?
# 192013                                                                                                           Are you a teacher?
# 67591                                                                                                  Do you use NuSkin skin care.
# 99103                                                                                                  are you married or anything?
# 82074                                                                                                               Right or wrong?
#
#        act  is_qy  does_rule  keyword_startswith
# 32382   qy   True      False               False
# 101597  qy   True      False               False
# 74708   qy   True      False                True
# 171604  qy   True      False               False
# 161404  qy   True      False               False
# 36230   qy   True      False               False
# 185678  qy   True      False                True
# 120286  qy   True      False               False
# 165218  qy   True      False               False
# 31146   qy   True      False               False
# 88471   qy   True      False                True
# 156333  qy   True      False                True
# 11500   qy   True      False               False
# 12469   qy   True      False               False
# 48146   qy   True      False               False
# 53672   qy   True      False               False
# 22945   qy   True      False               False
# 194059  qy   True      False                True
# 84040   qy   True      False               False
# 28565   qy   True      False               False
# 150841  qy   True      False               False
# 107986  qy   True      False               False
# 156495  qy   True      False               False
# 46040   qy   True      False                True
# 22595   qy   True      False               False
# 87083   qy   True      False               False
# 192013  qy   True      False                True
# 67591   qy   True      False               False
# 99103   qy   True      False                True
# 82074   qy   True      False               False

# %% [markdown]
# ### Rules

# %%
def rule_1(sentence):
    sentence = sentence.lower().strip()
    return 'does' in sentence and sentence.endswith('?')

def rule_2(sentence):
    keywords = ['do', 'does', 'did', 'are', 'is', 'was', 'should']
    startswith = any(sentence.lower().startswith(i) for i in keywords)
    return startswith and sentence.endswith('?')

def rule_3(sentence):
    return sentence.endswith('?')

# %%
rules = [ ('does_rule', rule_1), ('keyword_startswith', rule_2), ('endswith_?', rule_3) ]

# %% [markdown]
# ### Labeling

# %%
for name, rule in rules:
    swda[name] = swda['utterance'].apply(rule)

# %%
swda
# Out:
#        speaker  \
# 0            A
# 1            A
# 2            B
# 3            A
# 4            B
# ...        ...
# 199757       B
# 199758       B
# 199759       B
# 199760       B
# 199761       A
#
#                                                                                       utterance  \
# 0                                                                                         Okay.
# 1                        So, What kind of experience do you, do you have, then with child care?
# 2                                                I guess, I think, uh, I wonder if that worked.
# 3                                                                        Does it say something?
# 4                                                                      I think it usually does.
# ...                                                                                         ...
# 199757                               and I know they've, there's a lot of refineries down there
# 199758                        and that, that's some pretty potent stuff they put up in the air.
# 199759                                                   I, but I don't know how, uh, you know,
# 199760       there's a difference in what you can smell and what you, uh, you know, what's bad.
# 199761  Be interesting to see when, as Mexico develops industrially whether, you know, without,
#
#                     act  is_qy  does_rule  keyword_startswith  endswith_?
# 0       fo_o_fw_"_by_bc  False      False               False       False
# 1                    qw  False      False               False        True
# 2                  qy^d  False      False               False       False
# 3                    qy   True       True                True        True
# 4                    sd  False      False               False       False
# ...                 ...    ...        ...                 ...         ...
# 199757               sd  False      False               False       False
# 199758               sv  False      False               False       False
# 199759               sd  False      False               False       False
# 199760               sv  False      False               False       False
# 199761               sv  False      False               False       False
#
# [199762 rows x 7 columns]

# %% [markdown]
# ### Evaluation

# %%
for name, rule in rules:
    predicted_true = swda[swda[name]]
    precision = predicted_true['is_qy'].mean()
    
    true_examples = swda[swda['is_qy']]
    recall = true_examples[name].mean()
    
    print(name)
    print(len(predicted_true))
    print(precision)
    print(recall)
    print()
# Out:
# does_rule
# 213
# 0.5727699530516432
# 0.02582010582010582
#
# keyword_startswith
# 1715
# 0.8303206997084548
# 0.30137566137566135
#
# endswith_?
# 7956
# 0.4356460532931121
# 0.7335449735449735

# %% [markdown]
# ### Manual analysis

# %%
swda[swda['keyword_startswith']].sample(20)
# Out:
#        speaker  \
# 91164        A
# 70948        B
# 123016       A
# 14245        B
# 58755        B
# 69589        A
# 153953       A
# 33391        A
# 186683       B
# 53377        A
# 143302       A
# 111781       A
# 175657       B
# 71502        A
# 29451        B
# 17622        A
# 115119       B
# 10442        A
# 156355       B
# 99650        A
#
#                                                                                             utterance  \
# 91164                                                                             Do you have a boat?
# 70948                                                                                  Is that right?
# 123016                                                     Do you know anybody that's ever done this?
# 14245                                                                    Do you like the job sharing?
# 58755                                                              Do they require you to presort it?
# 69589                                                                              do you have a P C?
# 153953                                                                                        Do you?
# 33391                                                                                        Did you?
# 186683                                                             Are you a Vietnam veteran, Dudley?
# 53377           Do you have a lot of property, I mean a lot of yard around your house now, in Denton?
# 143302                                                               Do you sing or knit or anything?
# 111781                                                                          Did they die or what?
# 175657                                                                              Did you go there?
# 71502                                                              Are you in the middle of anything?
# 29451   is that the one where they, uh, he always got this, this tape recording that self-destructed?
# 17622                                                     do the schools emphasize the metric system?
# 115119                                    Do you have your, uh, loans through the Texas Credit Union?
# 10442                                                                                         Do you?
# 156355                                                                     do you know John Qumenato?
# 99650                                                    Do you, do you think that should be changed?
#
#        act  is_qy  does_rule  keyword_startswith  endswith_?
# 91164   qy   True      False                True        True
# 70948   qy   True      False                True        True
# 123016  qy   True      False                True        True
# 14245   qy   True      False                True        True
# 58755   qy   True      False                True        True
# 69589   qy   True      False                True        True
# 153953  bh  False      False                True        True
# 33391   bh  False      False                True        True
# 186683  qy   True      False                True        True
# 53377   qy   True      False                True        True
# 143302  qy   True      False                True        True
# 111781  qy   True      False                True        True
# 175657  qy   True      False                True        True
# 71502   qy   True      False                True        True
# 29451   qy   True      False                True        True
# 17622   qy   True      False                True        True
# 115119  qy   True      False                True        True
# 10442   bh  False      False                True        True
# 156355  qy   True      False                True        True
# 99650   qy   True      False                True        True
