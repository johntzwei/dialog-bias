# %%
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 100)

# %%
raw = pd.read_csv('qy_batch.csv')

# %%
raw.columns
# Out:
# Index(['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward',
#        'CreationTime', 'MaxAssignments', 'RequesterAnnotation',
#        'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds',
#        'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds',
#        'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime',
#        'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime',
#        'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate',
#        'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.g1',
#        'Input.q1', 'Input.r1', 'Input.g2', 'Input.q2', 'Input.r2', 'Input.g3',
#        'Input.q3', 'Input.r3', 'Input.g4', 'Input.q4', 'Input.r4', 'Input.g5',
#        'Input.q5', 'Input.r5', 'Input.g6', 'Input.q6', 'Input.r6', 'Input.g7',
#        'Input.q7', 'Input.r7', 'Input.g8', 'Input.q8', 'Input.r8', 'Input.g9',
#        'Input.q9', 'Input.r9', 'Input.g10', 'Input.q10', 'Input.r10',
#        'Input.g11', 'Input.q11', 'Input.r11', 'Input.g12', 'Input.q12',
#        'Input.r12', 'Answer.answer1', 'Answer.answer1.label',
#        'Answer.answer10', 'Answer.answer10.label', 'Answer.answer11',
#        'Answer.answer11.label', 'Answer.answer12', 'Answer.answer12.label',
#        'Answer.answer2', 'Answer.answer2.label', 'Answer.answer3',
#        'Answer.answer3.label', 'Answer.answer4', 'Answer.answer4.label',
#        'Answer.answer5', 'Answer.answer5.label', 'Answer.answer6',
#        'Answer.answer6.label', 'Answer.answer7', 'Answer.answer7.label',
#        'Answer.answer8', 'Answer.answer8.label', 'Answer.answer9',
#        'Answer.answer9.label', 'Approve', 'Reject'],
#       dtype='object')

# %%
data = []
for i,row in raw.iterrows():
    for j in range(1, 13):
        query = row['Input.q%d' % j]
        response = row['Input.r%d' % j]
        gender = row['Input.g%d' % j]
        
        if row['Answer.answer%d' % j] is not np.nan:
            answer = row['Answer.answer%d' % j]
        else:
            answer = row['Answer.answer%d.label' % j]
        
        data.append((row['HITId'], j, row['WorkerId'], gender, query, response, answer))

# %%
df = pd.DataFrame(data)
df.columns = ['HITId', 'q_idx', 'WorkerId', 'gender', 'query', 'response', 'answer']
flat = df

# %%
spammers = ['A2X295K4FFKJ8I', 'A17FG9GVV76H3', 'A3A0RP6IUR41PP', 'A9OOV3976AFYF']

# %% [markdown]
# ### Flatten data

# %%
data = []
for i, group in df.groupby(['HITId', 'q_idx']):
    row = []
    row.append(group.iloc[0]['HITId'])
    row.append(group.iloc[0]['gender'])
    row.append(group.iloc[0]['query'])
    row.append(group.iloc[0]['response'])
    for j in range(0,3):
        if j < len(group):
            row.append(group.iloc[j]['WorkerId'])
            row.append(group.iloc[j]['answer'])
    data.append(row)

# %%
df = pd.DataFrame(data)
df.columns = ['HITId', 'gender', 'query', 'response', 'WorkerId1', 'Answer1', 'WorkerId2', 'Answer2', 'WorkerId3', 'Answer3',]
df.head(1)
# Out:
#                             HITId gender  \
# 0  30Y6N4AHYPXN3KJ9HR3IQO9DARSRDM      W
#
#                                                     query  \
# 0  Is having an opinion an exclusive left wing privilege?
#
#                                                                                               response  \
# 0  It is, but only when it benefits them. The left has the upper hand in the media landscape in the...
#
#        WorkerId1         Answer1      WorkerId2       Answer2      WorkerId3  \
# 0  A17FG9GVV76H3  Definitely yes  APGX2WZ59OWDN  Probably yes  A2AWSN5CWONM8
#
#           Answer3
# 0  Definitely yes

# %%
def f(x):
    x = x.lower()
    if 'definitely' in x:
        return 'F'
    elif 'probably' in x:
        return 'P'
    else:
        return 'N'
    
df['Answer1.label'] = df['Answer1'].apply(f)
df['Answer2.label'] = df['Answer2'].apply(f)
df['Answer3.label'] = df['Answer3'].apply(f)

# %%
def f(x):
    x = x.lower()
    if 'definitely' in x:
        return 'I'
    elif 'probably' in x:
        return 'I'
    else:
        return 'N'
    
df['Answer1.coarse'] = df['Answer1'].apply(f)
df['Answer2.coarse'] = df['Answer2'].apply(f)
df['Answer3.coarse'] = df['Answer3'].apply(f)

# %%
# calculate no agreement
df['non-agreement'] = [ len(set([x['Answer1.label'], x['Answer2.label'], x['Answer3.label']])) == 3 for i,x in df.iterrows()]
print(len(df[df['non-agreement']]))
df[['gender', 'query', 'response']][df['non-agreement']]
# Out:
# 60
#     gender  \
# 17       M
# 26       M
# 28       W
# 35       W
# 38       M
# 41       M
# 49       M
# 60       W
# 83       M
# 97       M
# 105      W
# 110      W
# 119      M
# 126      W
# 147      W
# 167      W
# 172      W
# 173      M
# 178      W
# 188      W
# 210      W
# 227      W
# 232      W
# 238      W
# 248      W
# 252      M
# 280      M
# 289      M
# 295      M
# 313      W
# 315      M
# 327      W
# 328      M
# 352      W
# 356      M
# 365      M
# 368      M
# 411      W
# 413      W
# 416      W
# 418      W
# 419      W
# 439      W
# 441      W
# 453      M
# 454      M
# 461      M
# 465      M
# 467      M
# 480      W
# 488      M
# 495      W
# 529      W
# 530      W
# 543      M
# 558      W
# 574      W
# 583      M
# 586      W
# 592      W
#
#                                                                                                    query  \
# 17                                 Are you really that full of shit and up your own ass to realize that?
# 26      Do you ever see NFL fans complain the Luke Kuechly is overrated and isnt as good as Khalil Mack?
# 28                                                            Are these to be treated as natural deaths?
# 35                                     Does anybody have any recommendatons on types of video equipment?
# 38                                               Did you know that 18 veterans commit suicide every day?
# 41   Is having no games because people see the genre as unstable, too expensive to develop and with a...
# 49                                                                           Is the U.S. a police state?
# 60                                                                 do you *have* to have so many stones?
# 83                                                                        Do you not know what a CEO is?
# 97                                                               Are you seriously trying to quote mine?
# 105                                                                 Did we not also invent the Internet?
# 110                       Was your dad a WWII vet who believed his kid should blindly serve same as him?
# 119                                        Did you learn to read and write exclusively from your school?
# 126                                             Do you think you and your boyfriend will ever have kids?
# 147                                                Do you know what I was thinking about each pregnancy?
# 167                         Do you guys not understand how readily available sex is to attractive women?
# 172  Do you have any idea how absolutely awful and soul-crushing and destructive an emotionally abusi...
# 173                                                          Arent these the same folks who banned guns?
# 178  Do you really want to sign on with someone who is deliberately wrecking their body and whom youl...
# 188                                            Do you want your children to grow up thinking thats okay?
# 210                                   isnt a great place to stop because the next question is Okay, how?
# 227                                                             Dont you think youve put in enough time?
# 232                                                            Does your culture have any tampon stigma?
# 238                                    Does you both even know what the legal definition of marriage is?
# 248                                                                       Do guys do that kind of thing?
# 252                 Do you have any idea on what kind of champion you would want to play against people?
# 280                                                                      Did you buy a spare SATA cable?
# 289                                                             Are THESE people exempt from these laws?
# 295                                                                         Do I really sound like that?
# 313                                                                       Did you even read the website?
# 315                                                                       Did you even watch the video??
# 327                                         Doesnt that mean that the reaction is greater too not equal?
# 328                                                             Isnt that Xeon really, really expensive?
# 352                     Are you actually saying that all medicine is scientifically proven with science?
# 356                                                          Does anyone know which teams contacted him?
# 365                                                                        Did you not read what I said?
# 368           Do you really think the refs would even be able to call everything completely impartially?
# 411                                                           Did you really ever see a future with him?
# 413                               Did I have some standards about career and finances when I was single?
# 416                                                        Is anyone at all actually interested, though?
# 418                                                                    Do people STILL talk like that???
# 419                                                            Are the two of you in counselling at all?
# 439                                                       Dont you wish people would just take the hint?
# 441                                                            Does anything happen if I lose at my gym?
# 453  Do you believe that someone with an enthusiasts rig will not be a customer within the 70% market...
# 454                               Does contributing to a political campaign count as goods and services?
# 461                                                                      Does the text still make sense?
# 465             Does anyone else hate the fact you can only stream to your TV via one of their products?
# 467                                                               Do you need that good of a CPU though?
# 480                                  Is your husbands psychiatrist aware of his past intrusive thoughts?
# 488                                          Do you remember clearly something you watched 5 months ago?
# 495             Do you have Protect (from Conjurer) cross-classed then (since AST is your first healer)?
# 529                            Do all guys who want a MFF threesome already have a woman picked out too?
# 530                                Do you think the cheese cloth hold against the bones and the boiling?
# 543                                                       Is the second half the exact opposite results?
# 558          Do you ever think youll explain to your parents how you actually feel about your sexuality?
# 574                                                       Do you know the website Texts from Last Night?
# 583                                                Do you want congress to actually be run by lobbyists?
# 586                                                        Dont you have a Cecil Rhodes doll to fellate?
# 592                                               Do you realize theyre supposed to have a smell, right?
#
#                                                                                                 response
# 17                                               I have no idea what that is, but you're probably right.
# 26                                                           No, that's just the NFL fans, not everyone.
# 28                                                           If it's natural then I'm fine with that too
# 35                                                     A lot of people recommend Audio Technica ATH X4s.
# 38                                                                                        No they don't.
# 41                                                                 I would like to see a game like this.
# 49   I think it's called a country where citizens are free to exercise their rights to self defense a...
# 60                                                Yes... yes... you are correct... I have a ton of these
# 83                                                           I don't think he understands what a CEO is.
# 97                                           I just wanted to show you that I understood your reference.
# 105                                             I'm sure you could find some sources of this information
# 110                                                                 I don't think that's even an option.
# 119                                                                                         He is a bot.
# 126                       He's not married yet. I think he's thinking about it, but it's a long process.
# 147                                                         Oh, I do. I've done a few things in my life.
# 167                                                                                               It is?
# 172                                                     I've always said that people that have a abusive
# 173                                                                                    And banned booze?
# 178                                                                    I don't know, I have no idea what
# 188                                       Yes I want to be able to have children, but not have children.
# 210  It's a place where you stop and stop for a few minutes and then stop. It's like the place to sto...
# 227                                                  I have been playing since the beginning of December
# 232                                                    I'm actually from a country with no tampon stigma
# 238                                            I think they think the word marriage is used incorrectly.
# 248                                                                        I know that you guys do that.
# 252                                                I'm not sure what I'd want. Maybe a good champion. :P
# 280                                           It was a cable from the company that was used for testing.
# 289                                                                               Only if they're black.
# 295                                                      Well then, I'll just tell myself it was a joke.
# 313                                                The website was made before I even clicked this post.
# 315                                                                           I was just kidding dude...
# 327  Yes, but that's not the point. I'm saying they have the same number of reactions in a set of eve...
# 328                                     I believe so. It's like a little over 100 more than an i5 3570k.
# 352                             I'm saying that if I'm wrong about something, it's because it's science.
# 356                                                            The article says it was from the UOL team
# 365                                   I did but I can't read, it's just my brain trying to make up words
# 368                                        I know a ref who has a reputation for being pretty impartial.
# 411                 He's a very good player. Not sure about the future but he's a solid player for sure.
# 413  Yeah I'm in the same boat. I just feel like the only person who could possibly have done this is...
# 416                                                                 No one in this thread is interested.
# 418                                                                 I've heard it in a couple of places.
# 419                                                                                   Unfortunately, no.
# 439                          I don't think anyone in the world would be surprised if they took the hint.
# 441                                                                  I'm sure you can lose a few pounds.
# 453                                                                If they're selling at a loss, they're
# 454                                                              It's just like the American revolution!
# 461                                             It's a reference to the movie, the movie is a good movie
# 465          I don't. It's an awesome app. Just like the others you mentioned. It has a built in browser
# 467                                                      I do have the CPU, but I need to get a new GPU.
# 480                                                                yes. he was not very happy with this.
# 488                    He didn't watch 5 months ago he said it was a good thing, not the best thing ever
# 495                                     Thanks for that, I didn't notice that. I'll fix that in an edit.
# 529                                                  I think that is an issue of choice, not just women.
# 530  The bone is still a good source for calcium, and bones and calcium. The leather isn't a good sou...
# 543                                                                   Nope, just some minor differences.
# 558                                                                                       i dont feel it
# 574                                                                                    It's a great band
# 583                                              If congress can't pass a bill to stop it, it will stop.
# 586                                                                I was going to put that in there too.
# 592                                                            They're actually supposed to smell awful.

# %%
for i,row in df.iterrows():
    labels = [row['Answer1.label'], row['Answer2.label'], row['Answer3.label']]
    #print('%d\t%d\t%d' % (labels.count('F'), labels.count('P'), labels.count('N')) )

# %%
count = 0
for i,row in df.iterrows():
    labels = [row['Answer1.coarse'], row['Answer2.coarse'], row['Answer3.coarse']]
    #print('%d\t%d' % (labels.count('I'), labels.count('N')) )
    if labels.count('I') == 3 or labels.count('N') == 3:
        count += 1
print(count)
# Out:
# 423

# %%
for worker, group in flat.groupby('WorkerId'):
    print('---')
    print(worker)
    print(group.answer.value_counts())
# Out:
# ---
# A12GER5MS6M0J
# No information or doesn't make sense    5
# Probably yes                            4
# Probably no                             3
# Name: answer, dtype: int64
# ---
# A16MXC30ZQ2W82
# Probably yes                            10
# No information or doesn't make sense     2
# Name: answer, dtype: int64
# ---
# A17FG9GVV76H3
# Definitely yes                          88
# Probably yes                            16
# Probably no                              2
# No information or doesn't make sense     1
# Definitely no                            1
# Name: answer, dtype: int64
# ---
# A1IIDR9HLUB1MR
# Probably yes                            12
# Definitely yes                           6
# No information or doesn't make sense     3
# Definitely no                            2
# Probably no                              1
# Name: answer, dtype: int64
# ---
# A1PO4SLO8F4INJ
# Definitely yes                          4
# Probably yes                            3
# Probably no                             3
# No information or doesn't make sense    2
# Name: answer, dtype: int64
# ---
# A1VBZWAHLWQMXM
# Definitely no                           4
# Probably yes                            3
# Definitely yes                          3
# No information or doesn't make sense    2
# Name: answer, dtype: int64
# ---
# A1YXH2CG99VRCZ
# Probably yes                            4
# Probably no                             3
# Definitely yes                          2
# No information or doesn't make sense    2
# Definitely no                           1
# Name: answer, dtype: int64
# ---
# A1ZDR2UN7M92LI
# No information or doesn't make sense    22
# Definitely yes                          21
# Probably yes                            19
# Definitely no                           19
# Probably no                             15
# Name: answer, dtype: int64
# ---
# A20OP7NKFYLTM1
# Definitely yes    12
# Name: answer, dtype: int64
# ---
# A26VB424KM3RSX
# Definitely yes                          9
# Probably no                             8
# Definitely no                           7
# Probably yes                            7
# No information or doesn't make sense    5
# Name: answer, dtype: int64
# ---
# A2AWSN5CWONM8
# Definitely yes                          117
# Definitely no                            80
# No information or doesn't make sense     67
# Probably yes                             24
# Probably no                              12
# Name: answer, dtype: int64
# ---
# A2FIGBFE2WOMEP
# Definitely yes                          6
# No information or doesn't make sense    4
# Probably no                             1
# Definitely no                           1
# Name: answer, dtype: int64
# ---
# A2KYIJW5XVNUHE
# No information or doesn't make sense    5
# Probably yes                            5
# Probably no                             1
# Definitely yes                          1
# Name: answer, dtype: int64
# ---
# A2NV3M9EXUM13L
# Probably yes                            13
# No information or doesn't make sense     6
# Probably no                              5
# Name: answer, dtype: int64
# ---
# A2X295K4FFKJ8I
# Definitely yes                          351
# Probably yes                             91
# Probably no                               9
# No information or doesn't make sense      9
# Definitely no                             8
# Name: answer, dtype: int64
# ---
# A30HPFPIXZ6H42
# Probably yes                            8
# Probably no                             1
# Definitely yes                          1
# Definitely no                           1
# No information or doesn't make sense    1
# Name: answer, dtype: int64
# ---
# A35CL66BEUSJ5Z
# No information or doesn't make sense    6
# Probably yes                            4
# Probably no                             1
# Definitely yes                          1
# Name: answer, dtype: int64
# ---
# A38DC3BG1ZCVZ2
# Definitely yes                          77
# Definitely no                           66
# No information or doesn't make sense    56
# Probably yes                            30
# Probably no                             23
# Name: answer, dtype: int64
# ---
# A3A0RP6IUR41PP
# Definitely yes                          62
# Probably yes                            26
# Probably no                              4
# No information or doesn't make sense     2
# Definitely no                            2
# Name: answer, dtype: int64
# ---
# A3EPGKBKORYQVJ
# Probably yes                            5
# Definitely yes                          4
# No information or doesn't make sense    2
# Probably no                             1
# Name: answer, dtype: int64
# ---
# A3Q4G0PIUC8O1G
# Probably yes                            9
# No information or doesn't make sense    3
# Name: answer, dtype: int64
# ---
# A9BMO09FR4QAM
# Probably yes                            5
# No information or doesn't make sense    4
# Probably no                             3
# Name: answer, dtype: int64
# ---
# A9OOV3976AFYF
# Definitely yes                          52
# Probably yes                             4
# Probably no                              2
# Definitely no                            1
# No information or doesn't make sense     1
# Name: answer, dtype: int64
# ---
# AA4KPDV3A2QQ9
# Probably yes      7
# Definitely yes    3
# Probably no       2
# Name: answer, dtype: int64
# ---
# ADUJKUKFAKNFE
# No information or doesn't make sense    7
# Probably yes                            2
# Definitely no                           2
# Definitely yes                          1
# Name: answer, dtype: int64
# ---
# AL0DOBE6NUQR9
# Probably yes                            8
# Probably no                             2
# No information or doesn't make sense    1
# Definitely no                           1
# Name: answer, dtype: int64
# ---
# AOJJK61F8QF22
# Probably no                             4
# Probably yes                            3
# No information or doesn't make sense    2
# Definitely no                           2
# Definitely yes                          1
# Name: answer, dtype: int64
# ---
# APGX2WZ59OWDN
# No information or doesn't make sense    24
# Definitely yes                          24
# Definitely no                           18
# Probably yes                            12
# Probably no                              6
# Name: answer, dtype: int64
# ---
# ARPBDM5QZ4XQC
# No information or doesn't make sense    8
# Definitely yes                          7
# Probably no                             4
# Definitely no                           3
# Probably yes                            2
# Name: answer, dtype: int64
# ---
# AVG8X5VFQ57ZO
# Probably yes      8
# Definitely yes    3
# Probably no       1
# Name: answer, dtype: int64
# ---
# AVMRJOB0ZA7PB
# Definitely yes                          5
# Definitely no                           4
# No information or doesn't make sense    2
# Probably yes                            1
# Name: answer, dtype: int64
