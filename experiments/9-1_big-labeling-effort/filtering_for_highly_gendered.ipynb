# %%
import random
random.seed(119)
import pandas as pd
import csv
import itertools

# %%
def read(fn):
    fh = open(fn, 'rt')
    data = []
    for line in fh:
        line = line.split('\t')
        label = line[0].strip('!')
        temp = line[1].strip('!').split('<|endoftext|>')
        question, response = temp[0], temp[1]
        data.append((label, question, response))
    return data

# %%
men_data = read('../8-21_help-pipeline_on_gendered-questions/vanilla_sample_high_conf_equal.csv')
men_data = pd.DataFrame(men_data)
men_data.columns = ['gender', 'question', 'response']

# %%
def pronouns(x):
    keywords = [' he ', ' him ', ' she ', 'her', ' they ', ' them ', ' it ', 'is that', ' this ']
    return any(i in x.lower() for i in keywords)

def has_or(x):
    return 'or' in x.lower()

def rhetoric(x):
    keywords = ['shouldn\'t', 'wouldn\'t', 'couldn\'t']
    return any(x.lower().startswith(i) for i in keywords)

def too_short(x):
    return len(x.split(' ')) <= 5

# %%
men_data
# Out:
#       gender                                           question  \
# 0          M                                        Is winning?
# 1          W                                      Is she trans?
# 2          W                                      Did she live?
# 3          M                                      ISIS twitter?
# 4          W                                     Are you my ex?
# ...      ...                                                ...
# 59995      W  Do people in areas where the temperatures go b...
# 59996      M  Should we make anyone who wants to play Call o...
# 59997      M  Wasnt the bill just a change in definition of ...
# 59998      M  Are you seriously saying that the internet (wh...
# 59999      W  Does she really want to be ridiculed every tim...
#
#                                                 response
# 0                  Of a bit more than 6 1 now, it's not.
# 1                                      Nah she's a dude.
# 2            She lived a few minutes after the accident.
# 3                                                      .
# 4          If she's still around I'll send you the pics.
# ...                                                  ...
# 59995  Yes, often the people who forget their kids di...
# 59996  I see some of these on here. They sound scary....
# 59997                             I'll believe this one.
# 59998                    Did you think he never said it?
# 59999                It sounds like she is starting out.
#
# [60000 rows x 3 columns]

# %%
men_data['q_pronoun'] = men_data.question.apply(pronouns)
men_data['q_has_or'] = men_data.question.apply(has_or)
men_data['q_rhetoric'] = men_data.question.apply(rhetoric)
men_data['q_too_short'] = men_data.question.apply(too_short)

# %%
good_qs = men_data[~men_data.q_pronoun & ~men_data.q_has_or & ~men_data.q_rhetoric & ~men_data.q_too_short]
good_qs
# Out:
#       gender                                           question  \
# 106        W                              Do you mix in a bowl?
# 231        M                           do you want a gaming PC?
# 233        M                           Did u manage to get any?
# 256        W                          Do you tend to stay pale?
# 259        W                          Are you sure thats a she?
# ...      ...                                                ...
# 59880      M  Do you honestly believe that raising taxes on ...
# 59908      W  Are you that insecure about yourself that when...
# 59932      M  do you think that the tax-free compounding of ...
# 59964      M  Do any of those allegations have anything to d...
# 59965      W  Is the issue that its very women are oppressed...
#
#                                                 response  q_pronoun  q_has_or  \
# 106    No. This was my first homebrew and I was not u...      False     False
# 231                                      Yes, yes he do.      False     False
# 233                           A few but nothing of worth      False     False
# 256                  Not really, I usually go with pale.      False     False
# 259            Lucky I didn't even see the question mark      False     False
# ...                                                  ...        ...       ...
# 59880  This is the new way of the world. It's all ove...      False     False
# 59908  Is that a reasonable reaction I wonder if ther...      False     False
# 59932                   Not sure, never held one myself.      False     False
# 59964                                        No comment.      False     False
# 59965  I wish so, too. The worst is when you want a w...      False     False
#
#        q_rhetoric  q_too_short
# 106         False        False
# 231         False        False
# 233         False        False
# 256         False        False
# 259         False        False
# ...           ...          ...
# 59880       False        False
# 59908       False        False
# 59932       False        False
# 59964       False        False
# 59965       False        False
#
# [13740 rows x 7 columns]

# %%
len(good_qs.question.unique()) / len(men_data.question.unique())
# Out:
# 0.22977509231285667

# %%
len(good_qs.question.unique())
# Out:
# 1369

# %%
good_qs.gender.value_counts()
# Out:
# M    7740
# W    6000
# Name: gender, dtype: int64

# %%
m_good_qs = good_qs[good_qs.gender == 'M']
w_good_qs = good_qs[good_qs.gender == 'W']

# %%
writer = csv.writer(open('./highly_conf.csv', 'wt'))
writer.writerow(['index', 'text', 'label', 'gender'])

index = 0
for i, row in itertools.chain(m_good_qs.iterrows(), w_good_qs.iterrows()):
    writer.writerow((index, '[CLS] %s [SEP] %s [SEP]' % (row['question'], row['response']), 'n', row['gender']))
    index += 1
