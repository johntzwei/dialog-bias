# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
from collections import Counter

# %% [markdown]
# ### Read data

# %%
raw = pd.read_csv('./binary_helpfulness_mturk_results.csv')

# %% [markdown]
# ### Flatten data

# %%
data = []
for i,row in raw.iterrows():
    for j in range(1, 13):
        query = row['Input.q%d' % j]
        response = row['Input.r%d' % j]
        gender = row['Input.g%d' % j]
        
        if row['Answer.answer%d' % j] is not np.nan:
            answer = row['Answer.answer%d' % j]
        else:
            answer = row['Answer.answer%d.label' % j]
        
        data.append((row['HITId'], j, row['WorkerId'], gender, query, response, answer))

# %%
melted = pd.DataFrame(data)
melted.columns = ['HITId', 'q_idx', 'WorkerId', 'gender', 'query', 'response', 'answer']

# %%
# include spammers:
include = True
if not include:
    spammers = ['A3A0RP6IUR41PP']
    melted = melted[~melted.WorkerId.isin(spammers)].copy()

# %%
data = []
for i, group in melted.groupby(['HITId', 'q_idx']):
    row = []
    row.append(group.iloc[0]['HITId'])
    row.append(group.iloc[0]['gender'])
    row.append(group.iloc[0]['query'])
    row.append(group.iloc[0]['response'])
    for j in range(0,5):
        if j < len(group):
            row.append(group.iloc[j]['WorkerId'])
            row.append(group.iloc[j]['answer'])
    data.append(row)

# %%
flat = pd.DataFrame(data)
flat.columns = ['HITId', 'gender', 'query', 'response'] + \
    sum([ ['WorkerId%d' % i, 'answer%d' % i] for i in range(0,5) ], [])

# %%
flat.head(1)
# Out:
#                             HITId gender  \
# 0  31YWE12TE0DRJ74BZD6OFEL5Q7O7X4      W
#
#                                                query  \
# 0  What if you dont have friends or family to tur...
#
#                                             response       WorkerId0  answer0  \
# 0  Well, I guess you could get a psychiatrist or ...  A12JKMVUW5HNKO  Helpful
#
#         WorkerId1  answer1       WorkerId2  answer2      WorkerId3  answer3  \
# 0  A1ET2J1PIP0RGO  Helpful  A2ARIPM4X6WZAK  Helpful  AYWWE1UD0XJFB  Helpful
#
#        WorkerId4    answer4
# 0  AFIK3VBMMX6G6  Unhelpful

# %% [markdown]
# ### Collapse labels

# %%
flat.answer0.unique()
# Out:
# array(['Helpful', 'Unhelpful'], dtype=object)

# %%
def i_no_i(x):
    if 'Response satisfactorily' in x:
        return 'i'
    elif 'provides some' in x:
        return 'i'
    elif 'does not make sense' in x:
        return 'ni'
    elif 'provides no' in x:
        return 'ni'

# %% [markdown]
# ### Interannotator agreement

# %%
order=['Helpful', 'Unhelpful']
ls = []

for i, row in flat.iterrows():
    labels = [ row['answer%d' %i ] for i in range(0, 5) ]
    #labels = list(map(i_no_i, labels))
    unique, counts = np.unique(labels,return_counts=True)
    unique = unique.tolist()
    
    l = []
    for i in order:
        if i in unique:   
            idx = unique.index(i)
            count = counts[idx]
        else:
            count = 0
        l.append(str(count))
        ls.append(l)
    print('\t'.join(l))
# Out:
# 4	1
# 2	3
# 4	1
# 5	0
# 4	1
# 5	0
# 3	2
# 3	2
# 4	1
# 3	2
# 3	2
# 3	2
# 4	1
# 2	3
# 3	2
# 3	2
# 5	0
# 2	3
# 1	4
# 5	0
# 4	1
# 3	2
# 5	0
# 1	4
# 1	4
# 3	2
# 3	2
# 4	1
# 4	1
# 5	0
# 4	1
# 4	1
# 3	2
# 4	1
# 3	2
# 4	1
# 2	3
# 3	2
# 3	2
# 2	3
# 2	3
# 5	0
# 5	0
# 2	3
# 3	2
# 3	2
# 1	4
# 3	2
# 4	1
# 2	3
# 2	3
# 2	3
# 1	4
# 4	1
# 2	3
# 1	4
# 2	3
# 5	0
# 3	2
# 2	3
# 5	0
# 3	2
# 3	2
# 2	3
# 3	2
# 4	1
# 2	3
# 3	2
# 3	2
# 5	0
# 5	0
# 2	3
# 3	2
# 2	3
# 4	1
# 4	1
# 3	2
# 2	3
# 2	3
# 5	0
# 4	1
# 3	2
# 4	1
# 3	2
# 3	2
# 4	1
# 1	4
# 1	4
# 3	2
# 2	3
# 4	1
# 3	2
# 3	2
# 1	4
# 3	2
# 1	4
# 4	1
# 2	3
# 3	2
# 5	0
# 2	3
# 3	2
# 3	2
# 3	2
# 5	0
# 3	2
# 5	0
# 2	3
# 3	2
# 2	3
# 4	1
# 2	3
# 2	3
# 2	3
# 4	1
# 0	5
# 3	2
# 2	3
# 5	0
# 2	3

# %%
# number of near agreements
np.mean([ '3' in i for i in ls ])
# Out:
# 0.5666666666666667

# %% [markdown]
# collapsed:
# 54.67%
# Kappa: 0.09

# %% [markdown]
# ### Majority labels

# %%
def majority(x, collapse=i_no_i, n=5):
    labels = [ x['answer%d' % i] for i in range(0, n)]
    labels = [ i for i in labels if i ]
    labels = list(map(collapse, labels))
    
    c = Counter(labels)
    commons = c.most_common(2)
    
    if len(commons) > 1 and commons[0][1] == commons[1][1]:
        return 'tie'
    else:
        return commons[0][0]

def near_majority(x, collapse=lambda x: x, n=5):
    labels = [ x['answer%d' % i] for i in range(0, n)]
    labels = [ i for i in labels if i ]
    labels = list(map(collapse, labels))
    
    c = Counter(labels)
    commons = c.most_common(2)
    
    return commons[0][1] == 3

# %%
flat['binary_majority'] = flat.apply(majority, axis=1)
flat['near_majority'] = flat.apply(near_majority, axis=1)
flat['majority'] = flat.apply(lambda x: majority(x, collapse=lambda x:x), axis=1)

# %% [markdown]
# ### Analysis

# %%
for i, group in flat.groupby('gender'):
    print(i)
    print(group.majority.value_counts(normalize=True))
# Out:
# M
# Helpful      0.666667
# Unhelpful    0.333333
# Name: majority, dtype: float64
# W
# Helpful      0.666667
# Unhelpful    0.333333
# Name: majority, dtype: float64

# %%
for i, group in flat.groupby('gender'):
    print(i)
    print(group.binary_majority.value_counts(normalize=False))
# Out:
# M
# Series([], Name: binary_majority, dtype: int64)
# W
# Series([], Name: binary_majority, dtype: int64)

# %% [markdown]
# ### Identifying spammers

# %%
for i, group in melted.groupby('WorkerId'):
    print('WorkerId: %s' % i)
    print(group.answer.value_counts())
    print()
# Out:
# WorkerId: A12HLCUXMU9JYT
# Helpful      9
# Unhelpful    3
# Name: answer, dtype: int64
#
# WorkerId: A12JKMVUW5HNKO
# Helpful      75
# Unhelpful    45
# Name: answer, dtype: int64
#
# WorkerId: A1ET2J1PIP0RGO
# Helpful      110
# Unhelpful     10
# Name: answer, dtype: int64
#
# WorkerId: A1SYZTNU9WJAB7
# Helpful      14
# Unhelpful    10
# Name: answer, dtype: int64
#
# WorkerId: A2ARIPM4X6WZAK
# Helpful      47
# Unhelpful    37
# Name: answer, dtype: int64
#
# WorkerId: A2VYFHIU1GYQCD
# Unhelpful    8
# Helpful      4
# Name: answer, dtype: int64
#
# WorkerId: A33D6XFZHIRXMM
# Unhelpful    9
# Helpful      3
# Name: answer, dtype: int64
#
# WorkerId: A3E06RQAB3QSZS
# Helpful      15
# Unhelpful     9
# Name: answer, dtype: int64
#
# WorkerId: A9XX3BUUML3ST
# Helpful      6
# Unhelpful    6
# Name: answer, dtype: int64
#
# WorkerId: AA5ZDXAA2DLY1
# Unhelpful    25
# Helpful      11
# Name: answer, dtype: int64
#
# WorkerId: AFIK3VBMMX6G6
# Unhelpful    66
# Helpful      54
# Name: answer, dtype: int64
#
# WorkerId: AM5DZDG51U3XO
# Helpful      11
# Unhelpful     1
# Name: answer, dtype: int64
#
# WorkerId: AYWWE1UD0XJFB
# Helpful      7
# Unhelpful    5
# Name: answer, dtype: int64

# %%
spammers = ['A3A0RP6IUR41PP']

# %% [markdown]
# ### Qualitative analysis

# %%
flat.head(1)
# Out:
#                             HITId gender  \
# 0  31YWE12TE0DRJ74BZD6OFEL5Q7O7X4      W
#
#                                                                                                 query  \
# 0  What if you dont have friends or family to turn too, and counselling isnt covered by your medical?
#
#                                                       response  \
# 0  Well, I guess you could get a psychiatrist or psychologist.
#
#         WorkerId0  answer0       WorkerId1  answer1       WorkerId2  answer2  \
# 0  A12JKMVUW5HNKO  Helpful  A1ET2J1PIP0RGO  Helpful  A2ARIPM4X6WZAK  Helpful
#
#        WorkerId3  answer3      WorkerId4    answer4 binary_majority  \
# 0  AYWWE1UD0XJFB  Helpful  AFIK3VBMMX6G6  Unhelpful            None
#
#    near_majority majority permute
# 0          False  Helpful       W

# %%
flat[['gender', 'near_majority','majority', 'query', 'response']][flat.majority == 'Helpful'].sample(20)
# Out:
#     gender  near_majority majority  \
# 41       W          False  Helpful
# 94       M           True  Helpful
# 99       W          False  Helpful
# 57       W          False  Helpful
# 90       W          False  Helpful
# 91       W           True  Helpful
# 102      M           True  Helpful
# 35       M          False  Helpful
# 84       M           True  Helpful
# 72       W           True  Helpful
# 105      M           True  Helpful
# 88       W           True  Helpful
# 4        W          False  Helpful
# 33       M          False  Helpful
# 34       W           True  Helpful
# 58       W           True  Helpful
# 67       M           True  Helpful
# 101      W           True  Helpful
# 70       M          False  Helpful
# 30       W          False  Helpful
#
#                                                                                                    query  \
# 41                                                                  How is Imgur blocked but not Reddit?
# 94                              Whats so special about the time between the formation lap and the start?
# 99                                                                            What do you use to doodle?
# 57                                                                       What kind of thing do you read?
# 90                                                                         What province do you live in?
# 91                                                            How does that NOT HAPPEN to everyone else?
# 102                                   What the fuck did you just fucking say about me, you little bitch?
# 35                                  When have you ever made an interesting strategic choice about runes?
# 84                                                                  What is your source for these stats?
# 72                           Whats to say that patriarchal societies arent built on social conditioning?
# 105                                How the fuck else do you expect a legally binding issue to be solved?
# 88                                                    When you say Irish, you do mean in Ireland, right?
# 4                                                                               How did you get into it?
# 33                                                                  What the fuck are you lmaoing about?
# 34            What if you got a male roommate who was okay with your girlfriend sleeping over sometimes?
# 58                                                          What do you mean when you say family values?
# 67   However, how many people from Atlanta cheer for Georgia over Tech, the school thats actually in ...
# 101                                                    Howland Reed finally going to make an appearance?
# 70                                                                         What do you base that off of?
# 30                                                            How long are you staying with your friend?
#
#                                                                                                 response
# 41                                                                                    It's a private sub
# 94                                                    You can see the lap time in the video description.
# 99                                                                 I use a program called sketchbook pro
# 57   I read a lot of stuff, mostly fiction and a bit of fantasy. Mostly I read the occasional science...
# 90                                                                                       Alberta, Canada
# 91                                                                  I'm not sure but I think it's a bug.
# 102                                                         I was hoping it'd be a little more subtle...
# 35                                                                                   Not in a long time.
# 84                                                                                       Just googled it
# 72                                                                    I don't think that's a good thing.
# 105                       It's not an issue that is being resolved, it is an issue that has been solved.
# 88                                                                       Yeah. But I'm not from Ireland.
# 4                                    I was a student, got a job at a local business and moved to the US.
# 33                                                 I think he's trying to say that the title was a joke.
# 34                                                                         I would have to ask him first
# 58                                                       It's a reference to the movie The Big Lebowski.
# 67                                                            I'm not from ATL, but I'm a huge Tech fan.
# 101                                                                                   He's in the books.
# 70                                                                                    My own experience.
# 30   I am in the process of moving in with him. I think he is going to take me to the local shelter t...

# %%
flat[['gender', 'near_majority', 'majority', 'query', 'response']][flat.majority == 'Unhelpful'].sample(20)
# Out:
#     gender  near_majority   majority  \
# 36       M           True  Unhelpful
# 93       W          False  Unhelpful
# 39       M           True  Unhelpful
# 23       W          False  Unhelpful
# 117      M           True  Unhelpful
# 54       M           True  Unhelpful
# 51       M           True  Unhelpful
# 18       W          False  Unhelpful
# 46       W          False  Unhelpful
# 1        M           True  Unhelpful
# 78       W           True  Unhelpful
# 43       M           True  Unhelpful
# 95       M          False  Unhelpful
# 24       W          False  Unhelpful
# 13       W           True  Unhelpful
# 112      M           True  Unhelpful
# 119      M           True  Unhelpful
# 56       M           True  Unhelpful
# 73       W           True  Unhelpful
# 100      M           True  Unhelpful
#
#                                                                                                    query  \
# 36                                           When was the last Supreme Court case about burning jerseys?
# 93                                                              Whos to say you wont regret that choice?
# 39                                                               Who deserves blame in the Detroit case?
# 23                                            When I was young, probably about middle-school age (12-13?
# 117                Whats the big difference between a candidate who has a 3.8 vs a candidate with a 3.9?
# 54                                                      What 14 year-old is going to question his coach?
# 51                                                            Who the fuck was happy with Obamas spying?
# 18                                        How could you think a mans wife being pregnant wouldnt matter?
# 46                                                      How about you tell me what you mean by minority?
# 1                                                              What if you had scrolls like this, right?
# 78                                                                What does gender have to do with this?
# 43                                                                   How many scientists work at LOreal?
# 95                                                           What is your counter-argument to inflation?
# 24                       How often do you get to throw a crazy party and invite all the people you love?
# 13                                                                       What did you do to me, you ask?
# 112                                                          How much of the game do you think that was?
# 119  How many people can type 1 billion words per minute, convey tone of voice through text, charm pe...
# 56                                                 What games that you play are bottlenecked by the CPU?
# 73                                                                         How dumb can you possibly be?
# 100                          what will the landscape of pro wrestling look like when Vince McMahon dies?
#
#                                                                                        response
# 36                                               I remember the first time I saw a jersey burn.
# 93                              I don't know. I'm not a fan of the way things are going for me.
# 39                                                               No one. The DA was a good guy.
# 23                                                                  That was a pretty good joke
# 117  I'm not sure, but I'm guessing you're talking about the difference between a 3.9 and a 3.8
# 54                                  You know, I'm just going to guess you've never heard of it.
# 51                                            The same people who were happy with Obama spying.
# 18                                                                          It's just a theory.
# 46   I don't think there was a single person in the crowd who didn't know what they were doing.
# 1                                                        I don't think so, I have a lot of them
# 78                      I don't think there's anything to it, just that it's interesting to me.
# 43                                                                            I am one of them.
# 95                                        I have no idea. I have no idea what you mean by this.
# 24                                              I don't think I've ever been invited to a party
# 13                                                                    You're the one who asked!
# 112                      I didn't think it was that bad, I thought it was just a bit of a mess.
# 119                      I would imagine that the amount of money they can make is pretty high.
# 56                                                I play a lot of games and I have a GTX 750Ti.
# 73                                                              I'm a professional quote maker!
# 100                                                                It is a beautiful landscape.

# %%
pd.set_option('max_colwidth', 100)
flat[['gender', 'near_majority', 'majority', 'query', 'response']][(flat.gender == 'M') & (flat.majority != 'Helpful')]
# Out:
#     gender  near_majority   majority  \
# 1        M           True  Unhelpful
# 36       M           True  Unhelpful
# 39       M           True  Unhelpful
# 43       M           True  Unhelpful
# 49       M           True  Unhelpful
# 50       M           True  Unhelpful
# 51       M           True  Unhelpful
# 54       M           True  Unhelpful
# 56       M           True  Unhelpful
# 63       M           True  Unhelpful
# 71       M           True  Unhelpful
# 86       M          False  Unhelpful
# 95       M          False  Unhelpful
# 100      M           True  Unhelpful
# 112      M           True  Unhelpful
# 113      M           True  Unhelpful
# 115      M          False  Unhelpful
# 117      M           True  Unhelpful
# 119      M           True  Unhelpful
#
#                                                                                                    query  \
# 1                                                              What if you had scrolls like this, right?
# 36                                           When was the last Supreme Court case about burning jerseys?
# 39                                                               Who deserves blame in the Detroit case?
# 43                                                                   How many scientists work at LOreal?
# 49                                                                         What are you not wrong about?
# 50                                              What demands that the criteria be the same despite this?
# 51                                                            Who the fuck was happy with Obamas spying?
# 54                                                      What 14 year-old is going to question his coach?
# 56                                                 What games that you play are bottlenecked by the CPU?
# 63                                               How is Philly even close to Atlantas level of futility?
# 71                                             What happens if you attack first, and win in two minutes?
# 86                                               When was the last time Syracuse was ranked in football?
# 95                                                           What is your counter-argument to inflation?
# 100                          what will the landscape of pro wrestling look like when Vince McMahon dies?
# 112                                                          How much of the game do you think that was?
# 113  What club wouldnt want a club captain who has won the PL, FA cup, League Cup, Community Shield, ...
# 115                                   What the fuck did you just fucking say about me, you little bitch?
# 117                Whats the big difference between a candidate who has a 3.8 vs a candidate with a 3.9?
# 119  How many people can type 1 billion words per minute, convey tone of voice through text, charm pe...
#
#                                                                                        response
# 1                                                        I don't think so, I have a lot of them
# 36                                               I remember the first time I saw a jersey burn.
# 39                                                               No one. The DA was a good guy.
# 43                                                                            I am one of them.
# 49                            It's a reference to a movie, and it's just a reference to a song.
# 50                                                                    The criteria is the same.
# 51                                            The same people who were happy with Obama spying.
# 54                                  You know, I'm just going to guess you've never heard of it.
# 56                                                I play a lot of games and I have a GTX 750Ti.
# 63                                           Well, it is a city with a population of about 30k.
# 71                                                            You lose, and the timer runs out.
# 86                                                              When was the last time we were?
# 95                                        I have no idea. I have no idea what you mean by this.
# 100                                                                It is a beautiful landscape.
# 112                      I didn't think it was that bad, I thought it was just a bit of a mess.
# 113                 He's a regular in the EPL and the CL, and he's a regular in the league cup.
# 115                                                                              I don't get it
# 117  I'm not sure, but I'm guessing you're talking about the difference between a 3.9 and a 3.8
# 119                      I would imagine that the amount of money they can make is pretty high.

# %%
flat[['gender', 'binary_majority', 'query', 'response']][(flat.gender == 'W') & (flat.binary_majority != 'i')]
# Out:
#     gender binary_majority  \
# 0        W            None
# 2        W            None
# 3        W            None
# 4        W            None
# 5        W            None
# ..     ...             ...
# 108      W            None
# 109      W            None
# 110      W            None
# 111      W            None
# 118      W            None
#
#                                                                                                   query  \
# 0    What if you dont have friends or family to turn too, and counselling isnt covered by your medical?
# 2                                          However, what is so horrible about *actually* being friends?
# 3                                           How did you get into tea, if its only been about two years?
# 4                                                                              How did you get into it?
# 5                                                            What state are you guys in/the breeder in?
# ..                                                                                                  ...
# 108                                                                     What kind of thing do you read?
# 109                                             What does your husbands family usually do for holidays?
# 110                                                                  Whats the point in raging in ARAM?
# 111                                                how do you put a dollar amount on sleep deprivation?
# 118                                                                       What are you willing to risk?
#
#                                                                                                 response
# 0                                            Well, I guess you could get a psychiatrist or psychologist.
# 2    I think that's the point. The only thing that's horrible is that the person who made it probably...
# 3                         It's been about three years since I started, and it's been a great experience!
# 4                                    I was a student, got a job at a local business and moved to the US.
# 5                                                                          I am a Breeder in California.
# ..                                                                                                   ...
# 108                                                                                       The good ones.
# 109                            I'm not sure if I've ever had a holiday where the family wasn't involved.
# 110                                                           So you can get that last gold in the game.
# 111                                                                                     By not sleeping.
# 118                                               I'd risk the chance of being able to be an NBA player.
#
# [63 rows x 4 columns]

# %%
flat[['gender', 'near_majority', 'binary_majority', 'query', 'response']][(flat.near_majority)]
# Out:
# Empty DataFrame
# Columns: [gender, near_majority, binary_majority, query, response]
# Index: []

# %% [markdown]
# ### Statistical analysis

# %%
trials = []
for i in range(0, 1000): 
    shuffle = flat['gender'].copy()
    np.random.shuffle(shuffle)
    
    flat['permute'] = shuffle
    pt = list(flat.groupby('permute'))
    
    g1, g2 = pt[0][1], pt[1][1]
    
    t = np.sum(g1.binary_majority.value_counts()['Helpful']) - np.sum(g2.binary_majority.value_counts()['Helpful'])
    trials.append(t)

sns.distplot(trials)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/biases/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-527dcf1a56f3> in <module>
#       9     g1, g2 = pt[0][1], pt[1][1]
#      10
# ---> 11     t = np.sum(g1.binary_majority.value_counts()['Helpful']) - np.sum(g2.binary_majority.value_counts()['Helpful'])
#      12     trials.append(t)
#      13
#
# ~/anaconda3/envs/biases/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/anaconda3/envs/biases/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4417                     raise InvalidIndexError(key)
#    4418                 else:
# -> 4419                     raise e1
#    4420             except Exception:
#    4421                 raise e1
#
# ~/anaconda3/envs/biases/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Helpful'

# %%
trials = np.array(trials)
np.mean(trials >= 21)
# Out:
# 0.214

# %%
flat[['query', 'response']].to_csv('query_response.tsv', sep='\t', header=None, index=False)
