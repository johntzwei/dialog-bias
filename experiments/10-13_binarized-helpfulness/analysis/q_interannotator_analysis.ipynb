# %%
import pandas as pd
import numpy as np
from collections import Counter

# %% [markdown]
# ### Read data

# %%
raw = pd.read_csv('./Batch_4218619_batch_results.csv')

# %% [markdown]
# ### Flatten data

# %%
data = []
for i,row in raw.iterrows():
    for j in range(1, 13):
        query = row['Input.q%d' % j]
        response = row['Input.r%d' % j]
        gender = row['Input.g%d' % j]
        
        if row['Answer.answer%d' % j] is not np.nan:
            answer = row['Answer.answer%d' % j]
        else:
            answer = row['Answer.answer%d.label' % j]
        
        data.append((row['HITId'], j, row['WorkerId'], gender, query, response, answer))

# %%
melted = pd.DataFrame(data)
melted.columns = ['HITId', 'q_idx', 'WorkerId', 'gender', 'query', 'response', 'answer']

# %%
# include spammers:
include = False
if not include:
    spammers = ['A3A0RP6IUR41PP']
    melted = melted[~melted.WorkerId.isin(spammers)].copy()

# %%
data = []
for i, group in melted.groupby(['HITId', 'q_idx']):
    row = []
    row.append(group.iloc[0]['HITId'])
    row.append(group.iloc[0]['gender'])
    row.append(group.iloc[0]['query'])
    row.append(group.iloc[0]['response'])
    for j in range(0,5):
        if j < len(group):
            row.append(group.iloc[j]['WorkerId'])
            row.append(group.iloc[j]['answer'])
    data.append(row)

# %%
flat = pd.DataFrame(data)
flat.columns = ['HITId', 'gender', 'query', 'response'] + \
    sum([ ['WorkerId%d' % i, 'answer%d' % i] for i in range(0,5) ], [])

# %%
flat.head(1)
# Out:
#                             HITId gender  \
# 0  30Y6N4AHYPXN3KJ9HR3IQO9DAYNDRH      W
#
#                                                   query  \
# 0  What was your relationship like before the drinking?
#
#                                          response      WorkerId0  \
# 0  We were friends but he had a drinking problem.  APKTDTD9LK539
#
#                                         answer0       WorkerId1  \
# 0  Response satisfactorily answers the question  A33XH3FNYAJ4LE
#
#                                               answer1       WorkerId2  \
# 0  Response provides some information to the question  A3774HPOUKYTX7
#
#                                         answer2       WorkerId3  \
# 0  Response satisfactorily answers the question  A1X7PC5PH6JWIS
#
#                                               answer3 WorkerId4 answer4
# 0  Response provides some information to the question      None    None

# %% [markdown]
# ### Collapse labels

# %%
flat.answer0.unique()
# Out:
# array(['Response satisfactorily answers the question',
#        'Response does not make sense',
#        'Response provides some information to the question',
#        'Response provides no information to the question at all'],
#       dtype=object)

# %%
def i_no_i(x):
    if 'Response satisfactorily' in x:
        return 'i'
    elif 'provides some' in x:
        return 'i'
    elif 'does not make sense' in x:
        return 'ni'
    elif 'provides no' in x:
        return 'ni'

# %% [markdown]
# ### Interannotator agreement

# %%
order = ['Response satisfactorily answers the question', 'Response provides some information to the question', 'Response provides no information to the question at all', 'Response does not make sense']
order = ['i', 'ni']

for i, row in flat.iterrows():
    labels = [ row['answer%d' %i ] for i in range(0, 5) ]
    labels = list(map(i_no_i, labels))
    unique, counts = np.unique(labels,return_counts=True)
    unique = unique.tolist()
    
    l = []
    for i in order:
        if i in unique:   
            idx = unique.index(i)
            count = counts[idx]
        else:
            count = 0
        l.append(str(count))
    #print('\t'.join(l))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-170-03d8f7cc91a2> in <module>
#       4 for i, row in flat.iterrows():
#       5     labels = [ row['answer%d' %i ] for i in range(0, 5) ]
# ----> 6     labels = list(map(i_no_i, labels))
#       7     unique, counts = np.unique(labels,return_counts=True)
#       8     unique = unique.tolist()
#
# <ipython-input-169-08db48f444c8> in i_no_i(x)
#       1 def i_no_i(x):
# ----> 2     if 'Response satisfactorily' in x:
#       3         return 'i'
#       4     elif 'provides some' in x:
#       5         return 'i'
#
# TypeError: argument of type 'NoneType' is not iterable

# %% [markdown]
# non-collapsed:
# 37.83%
# Kappa: 0.17
#
# collapsed:
# 68.17%
# Kappa: 0.36

# %% [markdown]
# ### Majority labels

# %%
def majority(x, collapse=i_no_i, n=5):
    labels = [ x['answer%d' % i] for i in range(0, n)]
    labels = [ i for i in labels if i ]
    labels = list(map(collapse, labels))
    
    c = Counter(labels)
    commons = c.most_common(2)
    
    if len(commons) > 1 and commons[0][1] == commons[1][1]:
        return 'tie'
    else:
        return commons[0][0]

# %%
flat['binary_majority'] = flat.apply(majority, axis=1)
flat['majority'] = flat.apply(lambda x: majority(x, collapse=lambda x:x), axis=1)

# %% [markdown]
# ### Analysis

# %%
for i, group in flat.groupby('gender'):
    print(i)
    print(group.majority.value_counts(normalize=True))
# Out:
# M
# Response provides some information to the question         0.359375
# Response satisfactorily answers the question               0.296875
# tie                                                        0.250000
# Response provides no information to the question at all    0.078125
# Response does not make sense                               0.015625
# Name: majority, dtype: float64
# W
# Response provides some information to the question         0.303571
# tie                                                        0.196429
# Response does not make sense                               0.178571
# Response satisfactorily answers the question               0.178571
# Response provides no information to the question at all    0.142857
# Name: majority, dtype: float64

# %%
for i, group in flat.groupby('gender'):
    print(i)
    print(group.binary_majority.value_counts(normalize=False))
# Out:
# M
# i      47
# ni      9
# tie     8
# Name: binary_majority, dtype: int64
# W
# i      28
# tie    14
# ni     14
# Name: binary_majority, dtype: int64

# %% [markdown]
# ### Identifying spammers

# %%
for i, group in melted.groupby('WorkerId'):
    print('WorkerId: %s' % i)
    print(group.answer.value_counts())
    print()
# Out:
# WorkerId: A1198W1SPF1R4
# Response satisfactorily answers the question          6
# Response provides some information to the question    5
# Response does not make sense                          1
# Name: answer, dtype: int64
#
# WorkerId: A182N7RLXGSCZG
# Response satisfactorily answers the question          5
# Response does not make sense                          4
# Response provides some information to the question    3
# Name: answer, dtype: int64
#
# WorkerId: A1NSK7DA2WVAIW
# Response provides some information to the question         10
# Response does not make sense                                9
# Response satisfactorily answers the question                4
# Response provides no information to the question at all     1
# Name: answer, dtype: int64
#
# WorkerId: A1U3TT3VMH9FU9
# Response provides no information to the question at all    4
# Response satisfactorily answers the question               4
# Response does not make sense                               2
# Response provides some information to the question         2
# Name: answer, dtype: int64
#
# WorkerId: A1U8VXESVQPZFJ
# Response satisfactorily answers the question               4
# Response provides no information to the question at all    3
# Response provides some information to the question         3
# Response does not make sense                               2
# Name: answer, dtype: int64
#
# WorkerId: A1X7PC5PH6JWIS
# Response provides some information to the question         28
# Response satisfactorily answers the question               18
# Response provides no information to the question at all    15
# Response does not make sense                               11
# Name: answer, dtype: int64
#
# WorkerId: A1XM0SQUNC4EFH
# Response provides some information to the question         8
# Response satisfactorily answers the question               8
# Response provides no information to the question at all    7
# Response does not make sense                               1
# Name: answer, dtype: int64
#
# WorkerId: A22JMNUXDWJN9X
# Response provides some information to the question         7
# Response provides no information to the question at all    3
# Response satisfactorily answers the question               2
# Name: answer, dtype: int64
#
# WorkerId: A2C84QVRK3KG57
# Response satisfactorily answers the question               14
# Response does not make sense                                5
# Response provides some information to the question          4
# Response provides no information to the question at all     1
# Name: answer, dtype: int64
#
# WorkerId: A2D8QWQBZSXYI9
# Response satisfactorily answers the question               18
# Response provides some information to the question         14
# Response provides no information to the question at all    10
# Response does not make sense                                6
# Name: answer, dtype: int64
#
# WorkerId: A2LPAX5TMH2U4A
# Response provides some information to the question         9
# Response satisfactorily answers the question               8
# Response provides no information to the question at all    4
# Response does not make sense                               3
# Name: answer, dtype: int64
#
# WorkerId: A2R25RH05K0B68
# Response satisfactorily answers the question               8
# Response does not make sense                               7
# Response provides no information to the question at all    6
# Response provides some information to the question         3
# Name: answer, dtype: int64
#
# WorkerId: A32W24TWSWXW
# Response provides some information to the question    6
# Response satisfactorily answers the question          6
# Name: answer, dtype: int64
#
# WorkerId: A33D6XFZHIRXMM
# Response provides some information to the question         8
# Response provides no information to the question at all    6
# Response satisfactorily answers the question               6
# Response does not make sense                               4
# Name: answer, dtype: int64
#
# WorkerId: A33XH3FNYAJ4LE
# Response satisfactorily answers the question               37
# Response provides some information to the question         23
# Response provides no information to the question at all    10
# Response does not make sense                                2
# Name: answer, dtype: int64
#
# WorkerId: A3774HPOUKYTX7
# Response provides some information to the question         6
# Response provides no information to the question at all    4
# Response does not make sense                               1
# Response satisfactorily answers the question               1
# Name: answer, dtype: int64
#
# WorkerId: A3A0RP6IUR41PP
# Response satisfactorily answers the question               80
# Response provides some information to the question         15
# Response provides no information to the question at all     1
# Name: answer, dtype: int64
#
# WorkerId: A3BNORV3OWTWDZ
# Response provides some information to the question         5
# Response satisfactorily answers the question               4
# Response provides no information to the question at all    3
# Name: answer, dtype: int64
#
# WorkerId: AJD2Q9O3GMUEX
# Response provides some information to the question         6
# Response provides no information to the question at all    4
# Response does not make sense                               2
# Name: answer, dtype: int64
#
# WorkerId: AOBC82WDZD2H4
# Response does not make sense                               5
# Response provides some information to the question         5
# Response provides no information to the question at all    1
# Response satisfactorily answers the question               1
# Name: answer, dtype: int64
#
# WorkerId: APKTDTD9LK539
# Response provides some information to the question         19
# Response satisfactorily answers the question                8
# Response provides no information to the question at all     5
# Response does not make sense                                4
# Name: answer, dtype: int64
#
# WorkerId: ATB1I7DDFTR6B
# Response provides no information to the question at all    7
# Response provides some information to the question         3
# Response satisfactorily answers the question               2
# Name: answer, dtype: int64

# %%
spammers = ['A3A0RP6IUR41PP']

# %% [markdown]
# ### Qualitative analysis

# %%
flat[['gender', 'binary_majority', 'query', 'response']][flat.binary_majority == 'i'].sample(20)
# Out:
#     gender binary_majority  \
# 97       M               i
# 109      W               i
# 106      M               i
# 26       M               i
# 18       W               i
# 40       W               i
# 87       M               i
# 82       M               i
# 108      W               i
# 114      W               i
# 23       M               i
# 84       M               i
# 59       M               i
# 63       W               i
# 0        W               i
# 86       M               i
# 110      M               i
# 119      M               i
# 100      W               i
# 32       M               i
#
#                                                                                                    query  \
# 97         Be fucking honest, would you stand by if you saw a man slap a woman across the face at a bar?
# 109                                                Do your health services treat depression and anxiety?
# 106                                                             How do you illustrate a point like that?
# 26                          We havent won over a big name free agent (besides Dwight) since, who, TMac??
# 18                                                     you... shouldnt be honest about things like that?
# 40   Perhaps Im just magically friends with the only people in the world who dont have inappropriate ...
# 87                      If you were to draw up the ideal point guard for the Kings, what would you want?
# 82                           Is the issue of a takeover, partnership, or perhaps a new sponsorship deal?
# 108                      Yknow, how someone will use their thumb to roll in circles on top of your hand?
# 114                               But then, when those shoes wear out, why would you pay for more shoes?
# 23                                                                              Do you need a DVD drive?
# 84                           Is the issue of a takeover, partnership, or perhaps a new sponsorship deal?
# 59                                                                        Do you have a source for that?
# 63                                                     Go through all that and NOT go into the industry?
# 0                                                   What was your relationship like before the drinking?
# 86                                                                Is upgrading to a faster SSD worth it?
# 110                                        You used to be able to get... 4 different abilities, I think?
# 119  > With Buffalos attempts to make itself the state of New Yorks team, how successful do you think...
# 100                                                     Have you two ever considered couples counseling?
# 32                                                                       What country are you living in?
#
#                                                                                                 response
# 97                                                                                               I would
# 109                                               They do, but the depression is usually self inflicted.
# 106         You just draw a straight line and then draw a line of points, and then draw a straight line.
# 26                                                                             Tmac? I don't think so...
# 18                                                                      I am a human being, not a robot.
# 40                                                                                        I'm not alone!
# 87                                                                  I would want a center who can shoot.
# 82                                                           I think we have a new sponsor for this year
# 108                                      They're a lot easier to use than a thumb, but I've seen it done
# 114  I would have to buy a few more pairs, and that's the only reason I would do it for this particul...
# 23                                                                       I do not, but thanks for offer!
# 84                                                                New sponsor, new sponsor, new sponsor.
# 59                                                                              It's a meme on this sub.
# 63   I have a job in the industry and I'm already planning on going out and working in a few industries.
# 0                                                         We were friends but he had a drinking problem.
# 86                                                                     Yes. It should be a good upgrade.
# 110           You can get more than one at once. Just click the ability on the right side of the screen.
# 119  I don't think the Pats are doing too well, but I guess it's a good start to make them feel at home.
# 100                                                                                  Not yet but I will.
# 32                                                                            I'm living in South Africa

# %%
pd.set_option('max_colwidth', 100)
flat[['gender', 'binary_majority', 'query', 'response']][(flat.gender == 'M') & (flat.binary_majority != 'i')]
# Out:
#     gender binary_majority  \
# 8        M             tie
# 12       M             tie
# 15       M             tie
# 24       M             tie
# 36       M              ni
# 41       M              ni
# 47       M              ni
# 49       M             tie
# 56       M              ni
# 67       M             tie
# 71       M             tie
# 78       M             tie
# 79       M              ni
# 88       M              ni
# 92       M              ni
# 94       M              ni
# 115      M              ni
#
#                                                                                                    query  \
# 8    What is so fucking detestable about thousands of people crying and screaming in happiness over a...
# 12                                Blizzard might want to give a more polished product, but at what cost?
# 15                                            > Just too much parity nowadays for starters  What parity?
# 24                                                                But who would really want competition?
# 36   Edit: how could i forget to mention that on average 50+% of our games are blacked out in any sea...
# 41                                                                            You know what I also love?
# 47                                                    >Havent we been doing that for the last ten years?
# 49                   >How exactly is Facebook or youtube a progression of technology that is beneficial?
# 56                                                              All that magic rules set aside for Jews?
# 67                            >Ive tried talking to some women in circumcision  MENOPHOBIA: Circumcised?
# 71   <link>  1RMs:  Bench 110 kg  Incline Bench 85 kg (5 RM)  Squat 140 kg  Deadlift 180 kg  OHP 70 k...
# 78                                                                  Which bundle do you prefer the most?
# 79                                    What the fuck did you just fucking say about me, you little bitch?
# 88           On a small site that has a very simple way of serving pages and with a very small overhead?
# 92                               Take a moment to think: How available are glass shards in a restaurant?
# 94                                  So, most gamers you know paints a fuller picture than overall stats?
# 115  Allowing respecs on the fly, making gold a standard(seriously, who thinks having gold be worthle...
#
#                                                                                              response
# 8                                                                             It's just a prank, bro.
# 12                                  Blizzard might be able to get a better product, but at what cost?
# 15                                                                            It's just that, parity.
# 24        Who would want competition when they can just buy a car and drive the same way they do now?
# 36                                                             That's actually a very good statistic.
# 41   I like to use the term'not so much'to refer to the'not so much'that is not very good ', as well.
# 47                               You're right. I just realized that I posted this in a different sub.
# 49                                                 I agree, but it's the only thing keeping me alive.
# 56                                                                              You just made my day.
# 67                                                                          I'm glad someone said it!
# 71                                   I'm trying to keep it as close to the original post as possible.
# 78                                      I have the most money, but I've also bought the most bundles.
# 79                                                                               You can't even read?
# 88                                                           I think you missed the point of the post
# 92                                                                 I'm not even sure what that means.
# 94                                                                   You can tell from the way it is.
# 115                                                                It's like gold in the first place.

# %%
flat[['gender', 'binary_majority', 'query', 'response']][(flat.gender == 'W') & (flat.binary_majority != 'i')]
# Out:
#     gender binary_majority  \
# 1        W             tie
# 7        W              ni
# 11       W             tie
# 13       W             tie
# 19       W             tie
# 22       W             tie
# 27       W             tie
# 35       W              ni
# 37       W              ni
# 38       W              ni
# 50       W             tie
# 52       W             tie
# 53       W              ni
# 58       W              ni
# 60       W             tie
# 65       W              ni
# 72       W             tie
# 73       W              ni
# 74       W              ni
# 75       W              ni
# 76       W             tie
# 77       W             tie
# 83       W              ni
# 85       W              ni
# 89       W              ni
# 91       W             tie
# 105      W             tie
# 113      W              ni
#
#                                                                                                    query  \
# 1                                 Are you under the impression that breast milk or formula is not vegan?
# 7                                              I guess some guys might be surprised by how dirty we are?
# 11                                                            Its not about making things uncomfortable?
# 13                          Hanging around outside someones house and plastering stickers on a dumpster?
# 19   I know I can find something else to help with my mental issues, but when food is the only thing ...
# 22                                                                Im the *only* person hes attracted to?
# 27     As for not being able to drive, can you ask your boyfriend to take you, or take the bus with you?
# 35                                      Want to drive more than an hour outside of town for the weekend?
# 37                                                                   They SEW fake hair to their SCALPS?
# 38   Now, if /u/Vicous had PMed OP that in a less jokey, more oh God I got so hot reading your piss s...
# 50                                                               Is VS really considered to be that bad?
# 52   I know I can find something else to help with my mental issues, but when food is the only thing ...
# 53                                                                            That is no beuno, you dig?
# 58                                                     Are you adopting or kidnapping or something else?
# 60                                                    Do you think its just too abnormal of a situation?
# 65                                    Why do so many people have a problem with people being vegetarian?
# 72                                                       >You say you have to meet the person   Have to?
# 73                                            >a) am I doing anything wrong that I could do differently?
# 74                                                          Perhaps you meant to use definitely instead?
# 75                                                     What would be the female version of emasculating?
# 76                  I wish I could say that I found a way to be okay with their closeness, but honestly?
# 77   Its also kind of scary, because if something happened to you and you couldnt reach a phone, what...
# 83              >she suggested that we not try again for a while which got me slightly upset  Seriously?
# 85                                        Why is bed-sharing so intimate its reserved for relationships?
# 89                                                              Dont you think youve put in enough time?
# 91                                                 Find someone else to fill the room at 1 hours notice?
# 105                                                                   Can I ask how Dilantin is for you?
# 113  Im not usually in favor of creating more drama, but do you think these people are capable of bei...
#
#                                                                                  response
# 1                                                                 You can't milk a vegan.
# 7           It's like we're wearing nothing at all... nothing at all... nothing at all...
# 11                                                  It's about making them uncomfortable.
# 13                          That's a really good idea actually. I would love to see that.
# 19                                        I'm trying to make myself feel better, I guess.
# 22                           I don't know, but I would guess it is someone that is a fan.
# 27               It's going to be a bus, so I'm not sure if she'll be able to take him...
# 35                                                                  I'm in the same boat.
# 37                                                                                I wish!
# 38                                                                    You are a good man.
# 50                                            It's not bad, but it's definitely not good.
# 52                               I don't go to the beach. I stay in my room all day long.
# 53                                    It's a bit too small. I'm thinking of a better one.
# 58                                                       I don't know what you're asking.
# 60                                              I don't know, I don't know, I don't know.
# 65                                                            Why do people not get this?
# 72                                                                             I have to?
# 73                                                     I was going to say the same thing!
# 74                                                                          I'm not sure.
# 75   I think I might have to try that. I have been trying to figure that out for a while.
# 76                                                       It's okay. We'll be OK together.
# 77                                                                           I'd call 911
# 83                                                         I think you're doing it wrong.
# 85                                       I think it's a good way to keep a room together.
# 89                                                                         It's a joke :P
# 91                               I don't think that's the issue, but it's a good thought.
# 105     I like him, he's a little more of a physical presence, but he's still my captain.
# 113                                                                     You have a point.
