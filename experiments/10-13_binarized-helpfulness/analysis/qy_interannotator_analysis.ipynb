# %%
import pandas as pd
pd.set_option('max_colwidth', 100)
import numpy as np
from collections import Counter

# %% [markdown]
# ### Read data

# %%
raw = pd.read_csv('./Batch_4218958_batch_results.csv')

# %% [markdown]
# ### Flatten data

# %%
data = []
for i,row in raw.iterrows():
    for j in range(1, 13):
        query = row['Input.q%d' % j]
        response = row['Input.r%d' % j]
        gender = row['Input.g%d' % j]
        
        if row['Answer.answer%d' % j] is not np.nan:
            answer = row['Answer.answer%d' % j]
        else:
            answer = row['Answer.answer%d.label' % j]
        
        data.append((row['HITId'], j, row['WorkerId'], gender, query, response, answer))

# %%
melted = pd.DataFrame(data)
melted.columns = ['HITId', 'q_idx', 'WorkerId', 'gender', 'query', 'response', 'answer']

# %%
# include spammers:
include = False
if not include:
    spammers = ['A1NE8EMAHNHLQ6']
    melted = melted[~melted.WorkerId.isin(spammers)].copy()

# %%
data = []
for i, group in melted.groupby(['HITId', 'q_idx']):
    row = []
    row.append(group.iloc[0]['HITId'])
    row.append(group.iloc[0]['gender'])
    row.append(group.iloc[0]['query'])
    row.append(group.iloc[0]['response'])
    for j in range(0,5):
        if j < len(group):
            row.append(group.iloc[j]['WorkerId'])
            row.append(group.iloc[j]['answer'])
    data.append(row)

# %%
flat = pd.DataFrame(data)
flat.columns = ['HITId', 'gender', 'query', 'response'] + \
    sum([ ['WorkerId%d' % i, 'answer%d' % i] for i in range(0,5) ], [])

# %%
flat.head(1)
# Out:
#                             HITId gender  \
# 0  301KG0KX9CMNBG7QOX77G1G3QY52H5      M
#
#                                   query  \
# 0  Do I think Michigan wins ultimately?
#
#                                             response      WorkerId0  \
# 0  It's a toss up, but I have a feeling that Mich...  A7XVPJCI4Z8MC
#
#           answer0       WorkerId1       answer1      WorkerId2       answer2  \
# 0  Definitely yes  A1ET2J1PIP0RGO  Probably yes  AG1OG2FU9F09G  Probably yes
#
#        WorkerId3       answer3 WorkerId4 answer4
# 0  AB2JXV5YUJ1Y7  Probably yes      None    None

# %% [markdown]
# ### Collapse labels

# %%
flat.answer0.unique()
# Out:
# array(['Definitely yes', 'Probably yes', 'Probably no',
#        "No information or doesn't make sense", 'Definitely no'],
#       dtype=object)

# %%
def i_no_i(x):
    if 'No information' in x:
        return 'ni'
    else:
        return 'i'
    
def reg(x):
    if 'Definitely yes' in x or 'Definitely no' in x:
        return 'f'
    elif 'Probably yes' in x or 'Probably no' in x:
        return 'p'
    else:
        return 'n'

# %% [markdown]
# ### Interannotator agreement

# %%
order = ['f', 'p', 'n']
order = ['i', 'ni']

agree = 0
for i, row in flat.iterrows():
    labels = [ row['answer%d' %i ] for i in range(0, 5) if row['answer%d' %i ] != None ]
    labels = list(map(i_no_i, labels))
    unique, counts = np.unique(labels,return_counts=True)
    unique = unique.tolist()

    if any(counts >= 3):
        agree += 1

print(agree, len(flat))
print(agree / len(flat))
# Out:
# 113 120
# 0.9416666666666667

# %%
order = ['i', 'ni']
#order = ['f', 'p', 'n']

j = 0
for i, row in flat.iterrows():
    labels = [ row['answer%d' %i ] for i in range(0, 5) if row['answer%d' %i ] != None ]
    labels = list(map(i_no_i, labels))
    unique, counts = np.unique(labels,return_counts=True)
    unique = unique.tolist()
    
    l = []
    for i in order:
        if i in unique:   
            idx = unique.index(i)
            count = counts[idx]
        else:
            count = 0
        l.append(str(count))
        
    if len(labels) == 4:
        j += 1
        print('\t'.join(l))
print(j)
# Out:
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 1	3
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 1	3
# 3	1
# 4	0
# 4	0
# 3	1
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 3	1
# 4	0
# 4	0
# 2	2
# 4	0
# 3	1
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 3	1
# 4	0
# 4	0
# 4	0
# 2	2
# 2	2
# 1	3
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 3	1
# 2	2
# 4	0
# 4	0
# 4	0
# 4	0
# 4	0
# 3	1
# 4	0
# 4	0
# 2	2
# 4	0
# 4	0
# 2	2
# 3	1
# 4	0
# 4	0
# 2	2
# 3	1
# 4	0
# 72

# %% [markdown]
# non-collapsed:
# 42.58%
# Kappa: 0.17
#
# collapsed:
# 81.67%
# Kappa: 0.63

# %% [markdown]
# ### Majority labels

# %%
def majority(x, collapse=i_no_i, n=5):
    labels = [ x['answer%d' % i] for i in range(0, n)]
    labels = [ i for i in labels if i ]
    labels = list(map(collapse, labels))
    
    c = Counter(labels)
    commons = c.most_common(2)
    
    if len(commons) > 1 and commons[0][1] == commons[1][1]:
        return 'tie'
    else:
        return commons[0][0]

# %%
flat['binary_majority'] = flat.apply(majority, axis=1)
flat['majority'] = flat.apply(lambda x: majority(x, collapse=lambda x:x), axis=1)

# %%
for i, group in flat.groupby('gender'):
    print(i)
    print(group.majority.value_counts(normalize=False))
# Out:
# M
# tie                                     18
# Probably no                             10
# Probably yes                            10
# Definitely yes                           9
# Definitely no                            7
# No information or doesn't make sense     6
# Name: majority, dtype: int64
# W
# Definitely no                           16
# Definitely yes                          14
# No information or doesn't make sense     8
# Probably no                              8
# tie                                      8
# Probably yes                             6
# Name: majority, dtype: int64

# %%
for i, group in flat.groupby('gender'):
    print(i)
    print(group.binary_majority.value_counts(normalize=False))
# Out:
# M
# i      53
# ni      4
# tie     3
# Name: binary_majority, dtype: int64
# W
# i      54
# tie     4
# ni      2
# Name: binary_majority, dtype: int64

# %% [markdown]
# ### Identifying spammers

# %%
for i, group in melted.groupby('WorkerId'):
    print('WorkerId: %s' % i)
    print(group.answer.value_counts())
    print()
# Out:
# WorkerId: A122GX6WP52RVZ
# Definitely yes    18
# Probably yes      13
# Definitely no     12
# Probably no        5
# Name: answer, dtype: int64
#
# WorkerId: A1ET2J1PIP0RGO
# Definitely no                           21
# Definitely yes                          20
# Probably yes                            14
# Probably no                             11
# No information or doesn't make sense     6
# Name: answer, dtype: int64
#
# WorkerId: A1GS7JCUCVTLO2
# Probably no       6
# Probably yes      4
# Definitely yes    1
# Definitely no     1
# Name: answer, dtype: int64
#
# WorkerId: A1NE8EMAHNHLQ6
# Probably yes      71
# Definitely yes     1
# Name: answer, dtype: int64
#
# WorkerId: A1S6Y0P5M0HNWG
# No information or doesn't make sense    7
# Probably yes                            3
# Probably no                             1
# Definitely yes                          1
# Name: answer, dtype: int64
#
# WorkerId: A22VGT2F28LTWC
# No information or doesn't make sense    4
# Probably no                             4
# Definitely yes                          3
# Definitely no                           1
# Name: answer, dtype: int64
#
# WorkerId: A25UMSG5I4A82E
# Probably no                             4
# Definitely no                           4
# No information or doesn't make sense    3
# Probably yes                            1
# Name: answer, dtype: int64
#
# WorkerId: A2H0VR477QHYO7
# Probably yes                            4
# No information or doesn't make sense    3
# Definitely yes                          3
# Probably no                             1
# Definitely no                           1
# Name: answer, dtype: int64
#
# WorkerId: A2NV3M9EXUM13L
# Probably yes                            9
# No information or doesn't make sense    3
# Name: answer, dtype: int64
#
# WorkerId: A2U14TBAOQV0KK
# Definitely no                           15
# Probably no                              8
# Definitely yes                           6
# Probably yes                             5
# No information or doesn't make sense     2
# Name: answer, dtype: int64
#
# WorkerId: A2V4ZV1C7T906L
# Probably no                             3
# Probably yes                            3
# Definitely no                           3
# No information or doesn't make sense    2
# Definitely yes                          1
# Name: answer, dtype: int64
#
# WorkerId: A2VYFHIU1GYQCD
# Probably no                             5
# Probably yes                            3
# Definitely yes                          2
# No information or doesn't make sense    1
# Definitely no                           1
# Name: answer, dtype: int64
#
# WorkerId: A3633T8CM8SXW8
# Definitely no                           6
# Definitely yes                          3
# Probably no                             2
# No information or doesn't make sense    1
# Name: answer, dtype: int64
#
# WorkerId: A369K7I5SXBPNC
# Probably yes      6
# Probably no       4
# Definitely yes    1
# Definitely no     1
# Name: answer, dtype: int64
#
# WorkerId: A3A0RP6IUR41PP
# Definitely yes    11
# Probably yes       1
# Name: answer, dtype: int64
#
# WorkerId: A3D4P4V4M2G0SK
# No information or doesn't make sense    7
# Probably yes                            4
# Probably no                             1
# Name: answer, dtype: int64
#
# WorkerId: A3JYTT5ZHFKR7A
# Probably no                             4
# Definitely yes                          4
# Probably yes                            2
# No information or doesn't make sense    1
# Definitely no                           1
# Name: answer, dtype: int64
#
# WorkerId: A3KPQ7L5FS8SD6
# No information or doesn't make sense    3
# Definitely yes                          3
# Probably no                             2
# Probably yes                            2
# Definitely no                           2
# Name: answer, dtype: int64
#
# WorkerId: A3MUG02LJ4BM9F
# Probably yes      5
# Probably no       4
# Definitely yes    3
# Name: answer, dtype: int64
#
# WorkerId: A3NG205QJ48IM4
# Probably no                             4
# No information or doesn't make sense    3
# Definitely yes                          3
# Probably yes                            2
# Name: answer, dtype: int64
#
# WorkerId: A7XVPJCI4Z8MC
# Definitely yes    25
# Probably yes      11
# Name: answer, dtype: int64
#
# WorkerId: AB2JXV5YUJ1Y7
# Probably yes                            23
# Probably no                             21
# No information or doesn't make sense    15
# Definitely no                           15
# Definitely yes                          10
# Name: answer, dtype: int64
#
# WorkerId: AG1OG2FU9F09G
# Definitely no                           9
# Probably yes                            5
# No information or doesn't make sense    4
# Probably no                             3
# Definitely yes                          3
# Name: answer, dtype: int64
#
# WorkerId: AHT0WFH0HG5UE
# Definitely yes                          3
# Definitely no                           3
# No information or doesn't make sense    2
# Probably no                             2
# Probably yes                            2
# Name: answer, dtype: int64
#
# WorkerId: AZ1KTVBLOCNMM
# Definitely yes                          6
# No information or doesn't make sense    2
# Definitely no                           2
# Probably no                             1
# Probably yes                            1
# Name: answer, dtype: int64
#
# WorkerId: AZLBLEDRP6UYM
# Definitely yes                          4
# Definitely no                           3
# No information or doesn't make sense    2
# Probably no                             2
# Probably yes                            1
# Name: answer, dtype: int64

# %%
spammers = ['A1NE8EMAHNHLQ6']

# %% [markdown]
# ### Qualitative analysis

# %%
flat[['gender', 'query', 'response']][flat.binary_majority == 'ni']
# Out:
#    gender  \
# 5       M
# 12      W
# 40      M
# 64      M
# 80      W
# 86      M
#
#                                                                            query  \
# 5                                    Didnt you hear what Norbert Haug & co. say?
# 12  Do you really think that every single woman is weaker than every single man?
# 40        Did I mention how Rank 22 for the Artifact Weapon costs 64.000 points?
# 64                                          Did you even read the whole article?
# 80                            Did you know fast food drive thrus are on a timer?
# 86           Do you know a guide or article on how emulators such as RPCS3 work?
#
#                                         response
# 5                               What did he say?
# 12              I think you're misunderstanding.
# 40            I'm not sure what you're saying...
# 64                Did you even read the article?
# 80  Did you know that the sun rises in the east?
# 86         I think he was trying to make a joke.

# %%
flat[['gender', 'query', 'response']][flat.binary_majority == 'tie']
# Out:
#     gender  \
# 54       M
# 78       W
# 79       M
# 101      M
# 110      W
# 113      W
# 117      W
#
#                                                                                                    query  \
# 54   Do you *really* think one needs to sacrifice the (admittedly-small-but-not-zero) performance off...
# 78                                                                        Did you even read the website?
# 79                            Do you need to ally yourself with a group that could cause later blowback?
# 101                           Do you think your company will/can consistently improve their stock price?
# 110                           Did you want to put Top Gear on while we review our retirement portfolios?
# 113                           Did you want to put Top Gear on while we review our retirement portfolios?
# 117                          Did you not have some basic research skills course in high school at least?
#
#                                                                                                 response
# 54              I'm not sure. I don't know how the process works and that's a very large amount of work.
# 78                                  It's a joke, I know you are joking, I'm just saying it's a bad idea.
# 79                                                                                  It's a hypothetical.
# 101  I don't have a good understanding of what stock price is and what it should be. I'm not a stock ...
# 110                                              I think I will go for a walk and just chill in the car.
# 113                                       I'm just gonna take this as a compliment, and go about my day.
# 117                                                                             I was a pre med student.

# %%
flat[['gender', 'query', 'response']][flat.binary_majority == 'i'].sample(10)
# Out:
#     gender  \
# 18       M
# 49       M
# 71       W
# 37       M
# 65       M
# 33       W
# 38       M
# 114      W
# 34       M
# 56       M
#
#                                                                                                    query  \
# 18   Did you really think that NATO/EU expansionism up to Russian borders would occur without some ci...
# 49   Are you that dense that you think referendums should be held yearly until you get the result you...
# 71                                Doesnt that kind of mean the dogs baseline personality isnt wonderful?
# 37   Do you think that a football team uses more people through the course of a season than a basebal...
# 65                                                                    Are you getting yellow on the 3DS?
# 33                                                               Do people really feel its a racial law?
# 38                                          Do you know what would happen if we went to war with Russia?
# 114  Do you know why no amount of disputable studies on IQ will ever affect my own self worth as a wo...
# 34                                                     Are the Knicks going to be a good team next year?
# 56   Did you really think that NATO/EU expansionism up to Russian borders would occur without some ci...
#
#                                                                                                 response
# 18                  The Ukrainians have been fighting with Russia for years, it's only a matter of time.
# 49                                                                      I was being sarcastic, but yeah.
# 71                                                                 I'm pretty sure that is what it means
# 37                                    No, but the average person spends a lot of money on a sports team.
# 65   Yes. It's a bit annoying, but the blue screen is annoying and it's the only way I can use the ga...
# 33             No, but there's nothing wrong with using it. I personally have no problem with it either.
# 38                                                                     I do not. I've not been involved.
# 114                    Because it's not a measure of intelligence, it's a measure of emotional maturity.
# 34                                                           I think they'll be a good team this season.
# 56                            You are not wrong, but you can never count on a single person to be wrong.
